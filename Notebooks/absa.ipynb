# %% [markdown]
# ## Importing required libraries
#
# In this Python notebook, we will explore the exciting field of Natural Language Processing (NLP) and its practical applications using various libraries. NLP is a subfield of artificial intelligence that focuses on enabling computers to understand, interpret, and generate human language.
# We will use NLP to extract aspect based sentiments for customer reviews.
#
# To begin our journey, we will import the following essential libraries:
#
# 1. **pandas** (imported as `pd`): Pandas is a powerful library for data manipulation and analysis. It provides data structures like DataFrames that are widely used in handling textual data during NLP tasks.
#
# 2. **numpy** (imported as `np`): NumPy is a fundamental library for numerical computing in Python. It provides support for large, multi-dimensional arrays and matrices, making it invaluable for numerical processing in NLP.
#
# 3. **emoji**: The emoji library allows us to work with emojis within the text data. Emojis are becoming increasingly common in text communication, and this library facilitates their handling in NLP tasks.
#
# 4. **re**: The `re` module in Python stands for regular expressions. It is used for pattern matching and manipulation of strings. Regular expressions play a crucial role in preprocessing and extracting information from textual data.
#
# 5. **string**: The `string` module provides various functions and constants related to string manipulation. It comes in handy when dealing with text preprocessing and filtering out unwanted characters.
#
# 6. **collections.Counter**: This class from the `collections` module is useful for counting the occurrences of elements in a collection. It is especially helpful for analyzing the frequency distribution of words in text data.
#
# Additionally, we will dive into the world of NLP using the **spacy** library, which is a powerful and efficient NLP framework. We will leverage the `Tokenizer` from the `spacy.tokenizer` module to break down text into individual tokens or words. Furthermore, we will use the `pprint` module for pretty-printing the results and making them more readable.
#
# Let's import these libraries and get started with our exploration!

# %%
# Required Libraries

#Base and Cleaning 
import pandas as pd
import numpy as np
import emoji
import re
import string
from collections import Counter


#Natural Language Processing (NLP)
import spacy
from spacy.tokenizer import Tokenizer
from pprint import pprint

# %% [markdown]
# ## Importing Android and iOS App Reviews Data
#
# In this section, we will import the Android and iOS app reviews data from CSV files to perform our analysis. We will use the `pandas` library to read the CSV files and store the data in data frames for further exploration.
#
# ### Importing Android Reviews Data
#
# We will first import the Android app reviews data from the CSV file named `android_reviews.csv`. This file contains user reviews and feedback for various Android smartphones.

# %%
android_reviews = pd.read_csv("../Data collection/android_reviews_new.csv")

# %% [markdown]
# ### Importing iOS Reviews Data
# Next, we will import the iOS smartphone reviews data from the CSV file named ios_reviews.csv. This file contains user reviews and feedback for iPhone 11 and iPhone SE.

# %%
ios_reviews = pd.read_csv("../Data collection/ios_reviews.csv")

# %%
android_reviews.head(10)
# Out:
#                                               Review     Make
# 0                                               good  Samsung  \
# 1  No for that you have to spend $300 to buy a Ga...  Samsung
# 2       So no heart rate reader, no Sp02 reader... ?  Samsung
# 3       So no heart rate reader, no Sp02 reader... ?  Samsung
# 4  Abs123, 24 Jul 2021I bought Samsung ultra s21 ...  Samsung
# 5  I bought Samsung ultra s21 4 days ago and sinc...  Samsung
# 6  "The Always On Display also works at 60Hz - we...  Samsung
# 7  Bob, 05 Jul 2021I'd be interested to see if th...  Samsung
# 8  No SD card slot, no money from me. I have the ...  Samsung
# 9  I'm not a computer or technical savvy person, ...  Samsung
#
#               Model Software
# 0  Galaxy S21 Ultra  Android
# 1  Galaxy S21 Ultra  Android
# 2  Galaxy S21 Ultra  Android
# 3  Galaxy S21 Ultra  Android
# 4  Galaxy S21 Ultra  Android
# 5  Galaxy S21 Ultra  Android
# 6  Galaxy S21 Ultra  Android
# 7  Galaxy S21 Ultra  Android
# 8  Galaxy S21 Ultra  Android
# 9  Galaxy S21 Ultra  Android

# %%
ios_reviews.head(10)
# Out:
#                                               Review   Make Model Software
# 0  Very bad experience with this iPhone xr phone....  Apple    11      iOS
# 1  Amazing phone with amazing camera coming from ...  Apple    11      iOS
# 2  So I got the iPhone XR just today. The product...  Apple    11      iOS
# 3  I've been an android user all my life until I ...  Apple    11      iOS
# 4  I was delivered a phone that did not work imme...  Apple    11      iOS
# 5  It has been a month since I started using my i...  Apple    11      iOS
# 6  The phone is hanging. Video quality is not ver...  Apple    11      iOS
# 7  I'll use this review to mostly say what I'm no...  Apple    11      iOS
# 8  Went with the iPhone XR after over a month of ...  Apple    11      iOS
# 9                                              NOTE:  Apple    11      iOS

# %% [markdown]
# ## Data Exploration: Shape, Data Types, and Missing Values
#
# Before we dive into the analysis of Android and iOS app reviews, let's perform some initial data exploration to understand the structure and quality of our data frames.
#
# ### Checking the Shape of Data Frames
#
# To start, let's examine the shape of our data frames to understand the number of rows and columns in each data set.

# %%
# Shape of Android Reviews Data Frame
android_shape = android_reviews.shape
print(f"Android Reviews Data Frame Shape: {android_shape}")

# Shape of iOS Reviews Data Frame
ios_shape = ios_reviews.shape
print(f"iOS Reviews Data Frame Shape: {ios_shape}")
# Out:
# Android Reviews Data Frame Shape: (4664, 4)
# iOS Reviews Data Frame Shape: (14722, 4)

# %% [markdown]
# ### Checking Data Types
# Next, let's inspect the data types of the columns in both data frames. Understanding the data types is essential to ensure that the data is appropriately represented for further analysis.

# %%
# Data Types in Android Reviews Data Frame
android_data_types = android_reviews.dtypes
print("Data Types in Android Reviews Data Frame:")
print(android_data_types)

# Data Types in iOS Reviews Data Frame
ios_data_types = ios_reviews.dtypes
print("\nData Types in iOS Reviews Data Frame:")
print(ios_data_types)
# Out:
# Data Types in Android Reviews Data Frame:
# Review      object
# Make        object
# Model       object
# Software    object
# dtype: object
#
# Data Types in iOS Reviews Data Frame:
# Review      object
# Make        object
# Model       object
# Software    object
# dtype: object

# %% [markdown]
# ### Convert the values to string type
#
# To make sure all columns are strings, as there is no other data type in this data.

# %%
all_columns = list(android_reviews) # Creates list of all column headers
android_reviews[all_columns] = android_reviews[all_columns].astype(str)

all_columns = list(ios_reviews) # Creates list of all column headers
ios_reviews[all_columns] = ios_reviews[all_columns].astype(str)

# %% [markdown]
# ### Checking Missing Values
#
# Lastly, let's identify if there are any missing values in the data frames. Missing values can impact the quality of our analysis, so it's crucial to handle them appropriately.

# %%
"""
Removing null rows, since only reviews was 
fecthed and rest all the columns were hardcoded during csv creation,
we can safely drop these rows.
"""
print(len(android_reviews[android_reviews.Review.isnull()]))
print(len(ios_reviews[ios_reviews.Review.isnull()]))

android_reviews = android_reviews.dropna()
ios_reviews = ios_reviews.dropna()
# Out:
# 0
# 0

# %% [markdown]
# ## Data Cleaning: User Reviews Preprocessing
#
# In this section, we will focus on the essential task of cleaning and preprocessing the user reviews data. Raw user reviews often contain various elements that can affect the accuracy and effectiveness of our analysis. We will perform the following data cleaning steps to prepare the text data for further analysis:
#
# 1. **Handling URLs**: User reviews might contain URLs or hyperlinks that do not contribute to the sentiment analysis. We will remove these URLs to focus on the meaningful text content.
#
# 2. **Handling Emojis**: Emojis are graphical representations used to convey emotions. While they add expressiveness to text, they can be challenging to process during analysis. We will handle emojis to ensure they do not interfere with our NLP tasks.
#
# By performing these cleaning steps, we aim to transform the raw user reviews into a clean, concise, and meaningful form that is ready for further sentiment analysis.
#
# Let's proceed with the data cleaning process and transform our user reviews data into a more structured and meaningful format.

# %%
def give_emoji_free_text(text):
    """
    Removes emoji's from reviews
    Accepts:
        Text (reviews)
    Returns:
        Text (emoji free reviews)
    """
    return emoji.replace_emoji(text)

def url_free_text(text):
    '''
    Cleans text from urls
    '''
    text = re.sub(r'http\S+', '', text)
    return text

# Apply the function above and get tweets free of emoji's
call_emoji_free = lambda x: give_emoji_free_text(x)

# Apply `call_emoji_free` which calls the function to remove all emoji's
android_reviews['emoji_free_text'] = android_reviews['Review'].apply(call_emoji_free)
ios_reviews['emoji_free_text'] = ios_reviews['Review'].apply(call_emoji_free)

#Create a new column with url free tweets
android_reviews['url_free_text'] = android_reviews['emoji_free_text'].apply(url_free_text)
ios_reviews['url_free_text'] = ios_reviews['emoji_free_text'].apply(url_free_text)

# %% [markdown]
# ## Sentiment Analysis: Importing Pre-trained ABSA Checkpoints
#
# In this section, we will explore the fascinating world of Aspect-Based Sentiment Analysis (ABSA) using pre-trained checkpoints. ABSA is a specialized task within Natural Language Processing (NLP) that aims to identify sentiment polarity towards specific aspects or entities mentioned in text data.
#
# To simplify our ABSA implementation, we will utilize the powerful `pyabsa` library, which provides access to various pre-trained ABSA checkpoints. These checkpoints are pre-trained models that can accurately detect sentiments associated with different aspects in user reviews, product feedback, or any other text containing opinions about multiple aspects.
#
# ### Importing Available Checkpoints
#
# To get started, we will import the `available_checkpoints` function from `pyabsa`. This function allows us to retrieve a mapping of the available pre-trained ABSA checkpoints that we can use for our sentiment analysis tasks.

# %%
from pyabsa import available_checkpoints
checkpoint_map = available_checkpoints()
# Out:
# /bin/sh: nvidia-smi: command not found
# No CUDA GPU found in your device
# [2023-08-10 14:58:26] (2.3.1) PyABSA(2.3.1): If your code crashes on Colab, please use the GPU runtime. Then run "pip install pyabsa[dev] -U" and restart the kernel.
# Or if it does not work, you can use v1.16.27
#
#
#
#
# WARNING: When you fails to load a checkpoint, e.g., Unexpected key(s),
# Try to downgrade transformers<=4.29.0.
#
#
#
#
# [2023-08-10 14:58:36] (2.3.1) Please specify the task code, e.g. from pyabsa import TaskCodeOption
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:268: ResourceWarning: unclosed running multiprocessing pool <multiprocessing.pool.Pool state=RUN pool_size=1>
#   _warn(f"unclosed running multiprocessing pool {self!r}",
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# ### Importing ATEPCCheckpointManager
#
# To get started with aspect extraction, we will import the `ATEPCCheckpointManager` from `pyabsa`. This manager class provides convenient functions to access and manage pre-trained Aspect Term Extraction (ATE) checkpoints.
#
# #### Initializing the Aspect Extractor
# Next, we will initialize the aspect extractor using the get_aspect_extractor function from ATEPCCheckpointManager. This function allows us to obtain a pre-trained aspect extractor for ABSA.

# %%
from pyabsa import ATEPCCheckpointManager

aspect_extractor = ATEPCCheckpointManager.get_aspect_extractor(checkpoint='english',
                                   auto_device=True  # False means load model on CPU
                                   )
# Out:
# [2023-08-10 14:59:31] (2.3.1) Downloading checkpoint:english
# [2023-08-10 14:59:31] (2.3.1) Notice: The pretrained model are used for testing, it is recommended to train the model on your own custom datasets
# [2023-08-10 14:59:31] (2.3.1) Checkpoint already downloaded, skip
# [2023-08-10 14:59:31] (2.3.1) Load aspect extractor from checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43
# [2023-08-10 14:59:31] (2.3.1) config: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.config
# [2023-08-10 14:59:31] (2.3.1) state_dict: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.state_dict
# [2023-08-10 14:59:31] (2.3.1) model: None
# [2023-08-10 14:59:31] (2.3.1) tokenizer: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.tokenizer
# [2023-08-10 14:59:31] (2.3.1) Set Model Device: cpu
# [2023-08-10 14:59:31] (2.3.1) Device Name: Unknown
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.bias', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.classifier.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'mask_predictions.dense.bias', 'lm_predictions.lm_head.bias', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.LayerNorm.weight']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/convert_slow_tokenizer.py:446: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
inference_source = android_reviews['url_free_text'].to_list()
atepc_result = aspect_extractor.extract_aspect(inference_source=inference_source,  #
                          pred_sentiment=True,  # Predict the sentiment of extracted aspect terms
                          )
# Out:
# preparing ate inference dataloader: 100%|██████████| 4664/4664 [00:08<00:00, 530.28it/s]
# extracting aspect terms: 100%|██████████| 146/146 [58:48<00:00, 24.17s/it]
# preparing apc inference dataloader: 100%|██████████| 7992/7992 [03:09<00:00, 42.15it/s]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyabsa/tasks/AspectTermExtraction/prediction/aspect_extractor.py:567: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:248.)
#   lcf_cdm_vec = torch.tensor(
# classifying aspect sentiments:   0%|          | 0/250 [00:00<?, ?it/s]/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pyabsa/tasks/AspectTermExtraction/prediction/aspect_extractor.py:648: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   float(x) for x in F.softmax(i_apc_logits).cpu().numpy().tolist()
# classifying aspect sentiments: 100%|██████████| 250/250 [1:16:49<00:00, 18.44s/it]
# [2023-08-10 17:18:43] (2.3.1) The results of aspect term extraction have been saved in /Users/chiraghs/Library/Mobile Documents/com~apple~CloudDocs/UON/Dissertation/Notebooks/Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2023-08-10 17:18:43] (2.3.1) Example 0: good
# [2023-08-10 17:18:43] (2.3.1) Example 1: No for that you have to spend $ 300 to buy a <Galaxy:Neutral Confidence:0.9989> watch : D
# [2023-08-10 17:18:43] (2.3.1) Example 2: So no heart rate reader , no Sp02 reader . . . ?
# [2023-08-10 17:18:43] (2.3.1) Example 3: So no heart rate reader , no Sp02 reader . . . ?
# [2023-08-10 17:18:43] (2.3.1) Example 4: Abs123 , 24 Jul 2021I bought Samsung ultra s21 4 days ago and since day 1 its restarting on its own randomly , stuc . . . moreCheck a place you bought it
# [2023-08-10 17:18:43] (2.3.1) Example 5: I bought Samsung ultra s21 4 days ago and since day 1 its restarting on its own randomly , stucks at <android recovery:Negative Confidence:0.9985> - cause of recovery unknown plus forces you to reset your phone and doesn ' t starts until you reset and lose all your data tried every hack troubleshooting everything nothing worked . . . Need help . . . . Anyone ? ? ?
# [2023-08-10 17:18:43] (2.3.1) Example 6: " The <Always On Display:Negative Confidence:0.9171> also works at 60Hz - we expected this to be the place where we ' d see the promised 10Hz . Well , it is not . This could be a potential burn - in - related setting , though , which mandates refreshing those pixels every now and then . " Why would I want 120Hz from AOD ? It ' s only there to display notifications . I don ' t even slightly care about having " smoother " scrolling . I care a lot more about the content inside the app itself . HRR screens only pay dividends in gaming , that ' s it ! You can ' t change that fact .
# [2023-08-10 17:18:43] (2.3.1) Example 7: Bob , 05 Jul 2021I ' d be interested to see if they do the same thing that happened with the S6 - S7 Take awa . . . moreWow
# [2023-08-10 17:18:43] (2.3.1) Example 8: No <SD card:Negative Confidence:0.9968> slot , no money from me . I have the note ultra and I love the pen . I can ' t see me getting another phone without it . . . if I ever do get another one . . . which I won ' t for a solid 6 + years . It has all I want .
# [2023-08-10 17:18:43] (2.3.1) Example 9: I ' m not a computer or technical savvy person , nor do I spell great . I ' ve had my new galaxy phone for a few days there ' s a lot of great stuff so far . I ' m am overwhelmed with driving fright to a big store chain so I drive . 4 different states maybe 5 in one week . Lots of mountain to take video and pictures and such . I needed a reliable phone so here I go with the best phone and carrier Verizon with limited phone calls being lost . I remember my first phone was a flip phone . Today I have a what the heck in one phone
# [2023-08-10 17:18:43] (2.3.1) Example 10: Zollyzo , 09 Jun 2021Same here . They lost that right with a device without <expandable storage:Negative Confidence:0.9896> . I wonder what they w . . . moreI ' d be interested to see if they do the same thing that happened with the S6 - S7 Take away the <SD Card slot:Negative Confidence:0.8871> and use the new <design:Negative Confidence:0.9519> language as an excuse to fob off anyone that wanted it . Then next years model will add it back in as a brand new extra <feature:Positive Confidence:0.5485> lol !
# [2023-08-10 17:18:43] (2.3.1) Example 11: Hell dweller . , 29 Jun 2021Wife lost the <sim tray ejector tool:Negative Confidence:0.9622> / <pin:Negative Confidence:0.5432> . I used a paper clip instead and inserted it into the . . . moreDo the phone not come with <warranty:Neutral Confidence:0.6248> ?
# [2023-08-10 17:18:43] (2.3.1) Example 12: Anonymous , 30 Jun 2021Am I reading this correctly ? Are you implying it ' s your wife ' s fault ? Your mistake w . . . moreSome people just refuse to take responsibility for their own actions . I feel bad for his wife that has to put up with him . Must be a constant nightmare .
# [2023-08-10 17:18:43] (2.3.1) Example 13: Hell dweller . , 29 Jun 2021Wife lost the <sim tray ejector tool:Negative Confidence:0.9796> / <pin:Negative Confidence:0.6283> . I used a paper clip instead and inserted it into the . . . moreAm I reading this correctly ? Are you implying it ' s your wife ' s fault ? Your mistake was pushing a <pin:Negative Confidence:0.6283> in the wrong hole , which would have happened even if your wife didn ' t lose the original pin . Take accountability instead of blaming everyone but you .
# [2023-08-10 17:18:43] (2.3.1) Example 14: Wife lost the <sim tray ejector tool:Negative Confidence:0.9863> / pin . I used a paper clip instead and inserted it into the <microphone hole:Negative Confidence:0.7787> right next to the <sim tray:Negative Confidence:0.9674> which looks exactly like to hole on the sim tray . The <mic:Negative Confidence:0.7993> is dead . Completely ruined the brand new $ 1500 phone , not to mention the hell I will have to go thru with her . Thanks , Samsung for making the holes so they could be mistaken for one another , because people don ' t make mistakes and make a living out of starring at frame holes made in factories on random phones .
# [2023-08-10 17:18:43] (2.3.1) Example 15: Nice . one I like it
# [2023-08-10 17:18:43] (2.3.1) Example 16: Lin , 21 Jun 2021Is there a pen in s21 ? SPEN is compatible in Samsung S21 Ultra only but not have space for putting it in , you can use it separately .
# [2023-08-10 17:18:43] (2.3.1) Example 17: Is there a <pen:Neutral Confidence:0.9986> in s21 ?
# [2023-08-10 17:18:43] (2.3.1) Example 18: I want to buy this phone . . . .
# [2023-08-10 17:18:43] (2.3.1) Example 19: People complaining about the missing <SD Card Slot:Negative Confidence:0.9889> never tried to incrementally sync an android phone with a computer . . . ( Meaning : Plugging in to a computer and automatically detecting only new photos , syncing it to a library , and leaving the user the option to keep or remove on phone ) It is almost impossible over cable , and if you achieve to do it , it get ' s even more a cramp if you have 2 <storage locations:Negative Confidence:0.9863> ( <sd card:Negative Confidence:0.9743> and internal ) : I always find myself to have a full <storage:Negative Confidence:0.9668> , fighting for some free <internal storage:Negative Confidence:0.9976> to keep the phone working . . . it . is . a . horror . Again , people complaining about the missing <sdcard:Negative Confidence:0.9725> , never exceeded the limit of their <storage:Negative Confidence:0.9668> . : )
# [2023-08-10 17:18:43] (2.3.1) Example 20: People complaining about the missing <SD Card Slot:Negative Confidence:0.9889> never tried to incrementally sync an android phone with a computer . . . ( Meaning : Plugging in to a computer and automatically detecting only new photos , syncing it to a library , and leaving the user the option to keep or remove on phone ) It is almost impossible over cable , and if you achieve to do it , it get ' s even more a cramp if you have 2 <storage locations:Negative Confidence:0.9863> ( <sd card:Negative Confidence:0.9743> and internal ) : I always find myself to have a full <storage:Negative Confidence:0.9668> , fighting for some free <internal storage:Negative Confidence:0.9976> to keep the phone working . . . it . is . a . horror . Again , people complaining about the missing <sdcard:Negative Confidence:0.9725> , never exceeded the limit of their <storage:Negative Confidence:0.9668> . : )
# [2023-08-10 17:18:43] (2.3.1) Example 21: i wish they actually would stop using the 108mp sensor , in exchange for a much more usable 50mp sensor , however , since numbers can fool people , they ' ll keep increasing to numbers up to 1 gigapixel with some 100 - in - 1 pixel binning for 10mp image . it ' s honestly pathetic that samsung keeps wanting to push the megapixel race , in exchange for only 12mp . ( apple started this in 2015 with their 6s having 12mp , then after 2015 , samsung copied apple with 12mp sensors up until to sony making a quad - bayer sensor for 12mp output , then samsung scammed people with 108mp number that only outputs 12mp . ) i don ' t get it . make a real 33mp or 40mp rgb bayer sensor with a big size for 8k recording , and a software with an option to output 20 or 25mp by downscaling the 33 / 40mp image to that resolution instead . it had me expecting a lot on quad - bayers , so far the best quad - bayer / terapixel rn is the samsung isocell hmx , even though the 108mp number is a gimmick , it still gives me a lot of hope because it outputs 27mp which is quite a lot , and better than the " industry standard " 12mp .
# [2023-08-10 17:18:43] (2.3.1) Example 22: Nelson , 04 Jun 2021I ' m amazed as nobody seems to be concerned with the removal of the <Micro SD:Negative Confidence:0.8804> . To me it . . . moreSame here . They lost that right with a device without <expandable storage:Negative Confidence:0.9958> . I wonder what they were thinking . It ' s my number reason why I am not a fun of iPhone .
# [2023-08-10 17:18:43] (2.3.1) Example 23: I ' m amazed as nobody seems to be concerned with the removal of the <Micro SD:Neutral Confidence:0.9404> . To me it ' s a matter of freedom and choices , I have been a long Samsung customer but they lost right there . . . .
# [2023-08-10 17:18:43] (2.3.1) Example 24: AnonD - 961600 , 09 Feb 2021Absolutely agree . I THINK the <S21 line:Positive Confidence:0.9994> up is awesome
# [2023-08-10 17:18:43] (2.3.1) Example 25: Sham93 , 22 Apr 2021Hi All . . need some help with all awesome techies here . Im about to buy Samsung S21 Ultra , 16 . . . moreSM - G998B is the Exynos variant . SM - G9980 is the Snapdragon variant . In the SM - G9980 there are three different firmware options . Hong Kong CSC - TGY , Taiwan CSC - BRI and China - CSC - CHC . The South Korean variant SM - G998N used to have a Snapdragon SoC but it ' s now the Exynos variant . Of the three Asian Snapdragon variants your best option is the Hong Kong device , it has no carrier bloatware and is the closest to a pure <android experience:Negative Confidence:0.9946> . The Taiwan device has issues with 5G and the China device has restrictions on Google , Facebook , Snapchat among others The Hong Kong 512 GB device is just about sold out and only available from a handful of retailers in Hong Kong . They have the TGY Hong Kong firmware but they ' ve actualky manufactured in Vietnam . IMHO it ' s Samsung ' s best smartphone .
# [2023-08-10 17:18:43] (2.3.1) Example 26: Anonymous , 27 May 2021Actually not having <charger:Neutral Confidence:0.9222> and <usb cable:Neutral Confidence:0.8615> somehow doesn ' t really much bother me , because . . . moreIt didn ' t bother me at all a new Samsung 25w <charger:Neutral Confidence:0.9222> is only cheap here & I didn ' t need it anyways I have quite a collection nowdays
# [2023-08-10 17:18:43] (2.3.1) Example 27: CapG , 26 May 2021I like Samsung phones but not having a <charger:Negative Confidence:0.9577> or <earphones:Negative Confidence:0.9474> in the box is enough to make me ch . . . moreActually not having <charger:Negative Confidence:0.9577> and <usb cable:Neutral Confidence:0.8389> somehow doesn ' t really much bother me , because the cheaper cable and charger are everywhere , also with the higher build quality like nylon cable or flat thin cable , less tangled less damage The most important is now you can resale the phone with unit only higher than before
# [2023-08-10 17:18:43] (2.3.1) Example 28: I like Samsung phones but not having a <charger:Negative Confidence:0.9983> or <earphones:Negative Confidence:0.9985> in the box is enough to make me change my mind this time . It ' s like buying car without seats . I ' ll buy a Xaiomi Mi 11 Ultra or Oppo Find X3 Pro instead .
# [2023-08-10 17:18:43] (2.3.1) Example 29: Im still <waiting:Negative Confidence:0.9649> for my phone how long should i wait im tired of <waiting:Negative Confidence:0.9649> cause i don ' t know whether is real its already 2moths
# [2023-08-10 17:18:43] (2.3.1) Example 30: I take two or more pictures then warning sign show on my screen , your phone temperature is high please turn off your camera . Now I think better phone is Nokia 3310 then Samsung s21 ultra 5G .
# [2023-08-10 17:18:43] (2.3.1) Example 31: kookie , 07 May 2021You probably have a faulty device . Mine <charges:Negative Confidence:0.8077> perfectly fine with 25w charger in warm condit . . . moreHow warm does it get where you live ? Everyone in India where I live experience longer <charging times:Negative Confidence:0.9645> in summer .
# [2023-08-10 17:18:43] (2.3.1) Example 32: Sud , 26 Mar 2021Would I be better off getting <s20:Neutral Confidence:0.9772> ultra over the S21 ? yes
# [2023-08-10 17:18:43] (2.3.1) Example 33: farhanay999 , 09 May 2021Dear Users , Please let me know that which <Model:Neutral Confidence:0.9991> Number has Snap Dragon 888 <chipset:Neutral Confidence:0.9989> ? Rega . . . moreSM - G998U ( USA ) SM - G998U1 ( USA unlocked ) SM - G998W ( Canada ) SM - G9980 ( China ) All are <Snapdragon:Neutral Confidence:0.9965> variants
# [2023-08-10 17:18:43] (2.3.1) Example 34: Dear Users , Please let me know that which Model Number has Snap Dragon 888 <chipset:Neutral Confidence:0.9989> ? Regards Farhan
# [2023-08-10 17:18:43] (2.3.1) Example 35: Anonymous , 02 Apr 2021S21 Ultra is one of the best devices this year . I have been using Samsung phones for 10 years . . . moreAs for <ads:Negative Confidence:0.6703> Samsung does exactly the same but I ' ve got zero ads on my Xiaomi UK version
# [2023-08-10 17:18:43] (2.3.1) Example 36: Anonymous , 02 Apr 2021S21 Ultra is one of the best devices this year . I have been using Samsung phones for 10 years . . . moreXiaomi has <bloatware:Negative Confidence:0.9972> yes and so does Samsung who are still one of the worst and as for best phone ever I don ' t think so . I returned my S21 Ultra <cameras:Negative Confidence:0.94> were underwhelming for the <price:Negative Confidence:0.8738> paid
# [2023-08-10 17:18:43] (2.3.1) Example 37: SgRepeat , 07 May 2021Both the Fast & super fast <charging:Positive Confidence:0.9893> toggles are enabled . I ' ve just noticed that if . . . moreYou probably have a faulty device . Mine <charges:Positive Confidence:0.9317> perfectly fine with 25w charger in warm conditions and cold . . .
# [2023-08-10 17:18:43] (2.3.1) Example 38: Anonymous , 03 May 2021Just tap on the toggle next to “ <Fast charging:Neutral Confidence:0.9581> ” to turn on fast chargingBoth the Fast & super fast <charging:Neutral Confidence:0.9377> toggles are enabled .
#
#  I ' ve just noticed that if a fan is blowing at the phone or if the room temperature is around 24 ° C while charging , it charges faster by around 25 minutes . The moment I charge the phone in a room with temperatures of around 31 - 32 ° <C ,:Negative Confidence:0.7781> the charging time is prolonged by 25 minutes .
#
#  Does this happen with all Samsung phones or do I have a faulty unit ?
# [2023-08-10 17:18:43] (2.3.1) Example 39: SgRepeat , 23 Apr 2021My S21 Ultra is taking 1 hour and 30 minutes to <charge:Negative Confidence:0.661> from 5 - 100 % with the Samsung 25W Super . . . moreJust tap on the toggle next to “ <Fast charging:Neutral Confidence:0.9889> ” to turn on fast charging
# [2023-08-10 17:18:43] (2.3.1) Example 40: one plus is s21 ultra
# [2023-08-10 17:18:43] (2.3.1) Example 41: Sham93 , 22 Apr 2021Hi All . . need some help with all awesome techies here . Im about to buy Samsung S21 Ultra , 16 . . . moreI have just done a search on <google:Neutral Confidence:0.9988> . Your model number SM - G998B / DS is an international version which means it ' s the <exynos chipset:Neutral Confidence:0.9931> .
# [2023-08-10 17:18:43] (2.3.1) Example 42: My S21 Ultra is taking 1 hour and 30 minutes to <charge:Negative Confidence:0.851> from 5 - 100 % with the Samsung 25W Super Fast charger . I ' m using the cable supplied with the phone . Both the Fast charging and Super Fast charging options are enabled on the phone . Any idea what I ' m doing wrong ?
# [2023-08-10 17:18:43] (2.3.1) Example 43: Sham93 , 22 Apr 2021Hi All . . need some help with all awesome techies here . Im about to buy Samsung S21 Ultra , 16 . . . moreJust install " <cpu:Neutral Confidence:0.9934> z " apk . It wil tell you what <cpu:Neutral Confidence:0.9934> has been used on your device .
# [2023-08-10 17:18:43] (2.3.1) Example 44: Hi All . . need some help with all awesome techies here . Im about to buy Samsung S21 Ultra , <16gb ram:Neutral Confidence:0.9991> , 512 gb memory , made in Taiwan , UK version and the model number is SM - G998B / DS . The retailer told me its <snapdragon chipset:Neutral Confidence:0.7109> but as far as i know samsung only has snapdragon chipset on US and china version . Can someone help me . . if this model is really snapdragon or <Exynos:Neutral Confidence:0.9974> chipset . Thanks in advance Sham
# [2023-08-10 17:18:43] (2.3.1) Example 45: Hi all , how is it that I buy a phone worth 1000 dollars and ain ' t got <charger:Neutral Confidence:0.5762> ? How do they want me to <charge:Neutral Confidence:0.5794> that phone ? Where can I find charger appropriate to that phone ?
# [2023-08-10 17:18:43] (2.3.1) Example 46: Sweetmarie , 11 Apr 2021Does the S21 Ultra or S21 5g come with a <charger:Negative Confidence:0.674> and <ear buds:Negative Confidence:0.6752> ? No
# [2023-08-10 17:18:43] (2.3.1) Example 47: I got the S21 Ultra in January . Definitely faster than my previous phone , definitely heavier too . <Battery life:Neutral Confidence:0.55> is ok . Other than camera I found the bundled apps boring or too data collecting , so bye bye to those and it does not let you access your old favourite apps without alot of hurdles to jump . The phone does get hot . I turned on full 120hz because I can . Occasionally I get black lines across the <screen:Negative Confidence:0.9953> now . The phone came with wireless earphones which were awful and I paid extra for a wireless charging cradle which is good . All in all an ok phone for a premium price tag
# [2023-08-10 17:18:43] (2.3.1) Example 48: ME , 01 Apr 2021Samsung has all the right <hardware:Positive Confidence:0.9955> , what stopped me was and still is the constant forcing of s . . . moreWhat do you mean the <contacts:Negative Confidence:0.9985> are gone after a system update ? If the contacts are backed up with your Google account , you shouldn ' t lose them , but it ' s a bummer hearing that this happens .
# [2023-08-10 17:18:43] (2.3.1) Example 49: Does the S21 Ultra or S21 5g come with a <charger:Neutral Confidence:0.9942> and <ear buds:Neutral Confidence:0.9928> ?
# [2023-08-10 17:18:43] (2.3.1) Example 50: After winning the annevasary game how do you get the s 21
# [2023-08-10 17:18:43] (2.3.1) Example 51: Iam fine with <galaxy:Neutral Confidence:0.9953> note 8 , seems it will cover next 2 more years
# [2023-08-10 17:18:43] (2.3.1) Example 52: ME , 01 Apr 2021Samsung has all the right <hardware:Positive Confidence:0.6108> , what stopped me was and still is the constant forcing of s . . . moreS21 Ultra is one of the best devices this year . I have been using Samsung phones for 10 years and I never lost any contacts . I don ' t know what you are talking about . I am now using a Xiaomi phone and it has the worst version of <android:Negative Confidence:0.9984> that I ever used and never going to buy again . I am not saying that <One UI:Negative Confidence:0.9967> doesn ' t have problems but what you wrote here is total nonsense . Buy a S21 Ultra and you will see that the positive sides outruns the negative by a mile . You can ' t recommend someone to avoid such a good device just because you don ' t like that it has some apps from Sammy , it ' s again total nonsense . Go buy a Xiaomi with tons of bloatware and adds and then you will see what it means to use and experience a bad <software:Negative Confidence:0.9954> .
# [2023-08-10 17:18:43] (2.3.1) Example 53: Sud , 26 Mar 2021Would I be better off getting <s20:Neutral Confidence:0.9986> ultra over the S21 ? if only for the additional <features:Positive Confidence:0.9917> the ultra has but bear in mind there are some <camera:Negative Confidence:0.9941> issue which have sort of been fixed such as <autofocus:Negative Confidence:0.9963> in some instances . . . look up the review here on gsmarena as they mention its pros and cons
# [2023-08-10 17:18:43] (2.3.1) Example 54: Goz , 25 Mar 2021I liked my OnePlus7Pro , I enjoyed my Oppo Find X2 Pro but I have to say I ' ve come back to . . . moreSamsung has all the right hardware , what stopped me was and still is the constant forcing of samsung <software:Negative Confidence:0.9977> no one wants or uses and no ability to turn them off or choose anything else . Also Samsung have yet not figured out how to save the contacts after a system update . They are always gone after you ' ve updated your phone . Still have a samsung though because no other company have the right hardware . <Software:Neutral Confidence:0.5936> wise , your better off with almost anything else in the same price range .
# [2023-08-10 17:18:43] (2.3.1) Example 55: Would I be better off getting <s20:Neutral Confidence:0.9974> ultra over the S21 ?
# [2023-08-10 17:18:43] (2.3.1) Example 56: AlexP , 21 Mar 2021I own Oneplus 8 Pro and I ' m glad I don ' t own any Samsung since S8 + I liked my OnePlus7Pro , I enjoyed my Oppo Find X2 Pro but I have to say I ' ve come back to Samsung with the S21 Ultra 512 and am asking myself what stopped me buying Samsung phones . Absolutely flawless in every single way . I ' m a fan of the underdogs but there simply isn ' t one out there that can do the polished job Samsung can . These days that underdogs can ' t even claim to have that much of a lower <cost:Positive Confidence:0.959> either .
# [2023-08-10 17:18:43] (2.3.1) Example 57: Malik , 23 Mar 2021Heating issue while recording video . <Thumb impression:Negative Confidence:0.999> to unlock phone is very very pathetic . O . . . moreThe <ultrasonic sensor:Positive Confidence:0.8579> is incredible . Very reliable and don ' t have to wake the <screen:Neutral Confidence:0.9989> to use it
# [2023-08-10 17:18:43] (2.3.1) Example 58: Heating issue while recording video . <Thumb impression:Negative Confidence:0.9992> to unlock phone is very very pathetic . Oppo is far better then it . Phone <camera:Positive Confidence:0.9995> is good
# [2023-08-10 17:18:43] (2.3.1) Example 59: Nightmare101 , 20 Mar 2021Do you own one ? It ' s better than <OnePlus 8:Neutral Confidence:0.998> Pro and the others . I own Oneplus 8 Pro and I ' m glad I don ' t own any Samsung since S8 +
# [2023-08-10 17:18:43] (2.3.1) Example 60: AlexP , 20 Mar 2021Compared to any 2020 flagshipsDo you own one ? It ' s better than <OnePlus:Neutral Confidence:0.9984> 8 Pro and the others .
# [2023-08-10 17:18:43] (2.3.1) Example 61: Nightmare101 , 20 Mar 2021Compared to which phone ? Compared to any 2020 flagships
# [2023-08-10 17:18:43] (2.3.1) Example 62: AlexP , 14 Mar 2021Gsmarena add 1 more con Really bad <speaker:Negative Confidence:0.9989> , so review score should be 4 stars maximumCompared to which phone ?
# [2023-08-10 17:18:43] (2.3.1) Example 63: Gsmarena add 1 more con Really bad <speaker:Negative Confidence:0.999> , so review score should be 4 stars maximum
# [2023-08-10 17:18:43] (2.3.1) Example 64: Slow <charging:Negative Confidence:0.9989> , and can not talk longer than 10mins due to overheated issue
# [2023-08-10 17:18:43] (2.3.1) Example 65: SEXYBOO , 13 Mar 2021when u trying to use the <internet:Positive Confidence:0.9855> its really slow Definitely not . I ' m surprised how much faster it loads pages than my friend ' s S20 ultra .
# [2023-08-10 17:18:43] (2.3.1) Example 66: Anonymous , 12 Mar 2021No mention of 5G Network band list not even on their offical samsung website . WTF ! How will I . . . morewhen u trying to use the <internet:Negative Confidence:0.9981> its really slow
# [2023-08-10 17:18:43] (2.3.1) Example 67: proUser , 30 Jan 2021Just seen <demo:Negative Confidence:0.9946> piece at store . Its too huge to hold in one hand and heavy . I would still pre . . . morenone so far
# [2023-08-10 17:18:43] (2.3.1) Example 68: SEXYT BOO , 13 Mar 2021i got mine a few weeks ago so far its ok I ' m satisfied . Got son the <base:Positive Confidence:0.9992> s21 he ' s happy too .
# [2023-08-10 17:18:43] (2.3.1) Example 69: AnonD - 973296 , 27 Jan 2021u own one ? and if so which <version:Neutral Confidence:0.9961> do u have ? Just left from this comment to run got 1117 . Think you have an issue .
# [2023-08-10 17:18:43] (2.3.1) Example 70: Slym , 12 Feb 2021I got the s21 ultra , 128 GB Snapdragon . Its a beautiful phone , fixed the annoying <photo:Negative Confidence:0.9845> blue f . . . morei got mine a few weeks ago so far its ok
# [2023-08-10 17:18:43] (2.3.1) Example 71: No mention of 5G Network band list not even on their offical samsung website . WTF ! How will I know it 5G will work if I order one from Amazon USA , UK or Alibaba because I need 5G band n20
# [2023-08-10 17:18:43] (2.3.1) Example 72: No raw or <manual:Negative Confidence:0.9965> mode for the <periscope camera:Negative Confidence:0.9992> is a deal breaker in my opinion .
# [2023-08-10 17:18:43] (2.3.1) Example 73: pedronevessilva77 , 17 Feb 2021i have bought the oppo 256 gb ram and 8 gb rom 5g its a 4th of the <price:Positive Confidence:0.9952> , its prettier and in . . . moreLoooool ! . . . It would be better if you said you didn ' t have the money to buy the S21 . You would have made a much better figure ! ! ! . . .
# [2023-08-10 17:18:43] (2.3.1) Example 74: Rif , 02 Mar 2021is dxomark <camera:Negative Confidence:0.9439> score review true ? Yes it is true . I decided to sell it . . . Disappointed . .
# [2023-08-10 17:18:43] (2.3.1) Example 75: Really rubbish <wifi connection:Negative Confidence:0.9993> . So many issues and workarounds on the Web , I have tried them and still dropping constantly . Inferior product at sky high <prices:Negative Confidence:0.9992> . Will stick to my S10
# [2023-08-10 17:18:43] (2.3.1) Example 76: Rif , 02 Mar 2021is dxomark <camera:Neutral Confidence:0.8949> score review true ? I couldn ' t believe it
# [2023-08-10 17:18:43] (2.3.1) Example 77: is dxomark <camera:Neutral Confidence:0.9992> score review true ?
# [2023-08-10 17:18:43] (2.3.1) Example 78: Snake , 26 Feb 2021Hard to find 512gb of srorage 16gb of <ramTrue:Negative Confidence:0.788> , I have it in black <glass:Negative Confidence:0.9897> , changed the dead dull lifeless frosted black at the back . <Glass:Negative Confidence:0.7931> looks more shiny like <mirror:Negative Confidence:0.8412> looks . I payed £50 extra .
# [2023-08-10 17:18:43] (2.3.1) Example 79: Hi , does the front selfie camera record 24 fps video ?
# [2023-08-10 17:18:43] (2.3.1) Example 80: Tdubs , 27 Feb 2021Dude I have the same question . How does it <charge:Neutral Confidence:0.9416> ? it charges wirelessly or with <usb -:Neutral Confidence:0.9983> C .
# [2023-08-10 17:18:43] (2.3.1) Example 81: sam , 21 Feb 2021please can you explain howi can <charge:Negative Confidence:0.6361> the <battery:Negative Confidence:0.7757> ? Dude I have the same question . How does it charge ?
# [2023-08-10 17:18:43] (2.3.1) Example 82: Hard to find 512gb of srorage 16gb of ram
# [2023-08-10 17:18:43] (2.3.1) Example 83: Took a <moon:Positive Confidence:0.5029> photo tonight . It looked like a telescope photo . Awesome . Never had this happen before .
# [2023-08-10 17:18:43] (2.3.1) Example 84: please can you explain howi can <charge:Negative Confidence:0.6739> the <battery:Negative Confidence:0.6145> ?
# [2023-08-10 17:18:43] (2.3.1) Example 85: lousy . just one drop on our <laminate wooden floor:Negative Confidence:0.9946> , even with an otterbox defender case the <screen:Negative Confidence:0.542> scratched ( not deep ) . my old note 9 <gorilla glass:Positive Confidence:0.8949> is a lot better .
# [2023-08-10 17:18:43] (2.3.1) Example 86: Anonymous , 20 Feb 2021Apple <iphone:Neutral Confidence:0.9992> have only 20 watt so what ' s wrong with samsungApples 12 promax took 1 : 32 to fully charge . While the s21 ultra took only 1 : 11 to fully charge . So samsung is the winner .
# [2023-08-10 17:18:43] (2.3.1) Example 87: flagshipper , 20 Feb 2021very slow <charging:Negative Confidence:0.9982> . . not a flagship anymore . Apple <iphone:Negative Confidence:0.5413> have only 20 watt so what ' s wrong with samsung
# [2023-08-10 17:18:43] (2.3.1) Example 88: very slow <charging:Negative Confidence:0.9993> . . not a flagship anymore .
# [2023-08-10 17:18:43] (2.3.1) Example 89: pedronevessilva77 , 17 Feb 2021i have bought the oppo 256 gb <ram:Positive Confidence:0.9191> and <8 gb rom:Neutral Confidence:0.9964> 5g its a 4th of the <price:Negative Confidence:0.9928> , its prettier and in . . . moremy guy mixed up <ram:Positive Confidence:0.9191> and <rom:Positive Confidence:0.999> lol
# [2023-08-10 17:18:43] (2.3.1) Example 90: Dkhd , 31 Jan 2021I just got the S21Ultra 512gb <16gb Ram:Neutral Confidence:0.868> version . Tried the 12gb <ram:Positive Confidence:0.9756> , 16gb <ram:Positive Confidence:0.9756> is wa better . What are you doing which is better with 16gb RAM instead of 12 ?
# [2023-08-10 17:18:43] (2.3.1) Example 91: AnonD - 961600 , 09 Feb 2021Absolutely agree . sorry to disappoint , the S21 line seems to be doing pretty well , better than the S20 line
# [2023-08-10 17:18:43] (2.3.1) Example 92: JC , 13 Feb 2021Weird that GSMARENA HASNT UPDATED IPHONE 12 pro max numbers for <Antutu:Negative Confidence:0.9967> . My iPhone 12 Pro Max l . . . moreantutu is a bit sketchy imo
# [2023-08-10 17:18:43] (2.3.1) Example 93: i have bought the oppo 256 gb ram and 8 gb rom 5g its a 4th of the <price:Positive Confidence:0.9991> , its prettier and in my opinion a bit betteter than thae sam 21 . 399 euros man . . . i know what im talking abougt . think befoure you buy . . . all the best . . . oppo rules
# [2023-08-10 17:18:43] (2.3.1) Example 94: Vj , 09 Feb 2021Completely agree about the <charger:Negative Confidence:0.996> . Its just a marketing stunt to get more out of the customer . . . moreDoes the S21 Ultra provide free 1 TB cloud storage on <Microsoft One Drive:Neutral Confidence:0.9941> ? I googled it , but couldn ' t find anything .
# [2023-08-10 17:18:43] (2.3.1) Example 95: a dude , 13 Feb 2021actually buying a <charger:Neutral Confidence:0.5063> separately means you use more packaging just for the charger , but al . . . moreWeird that GSMARENA HASNT UPDATED IPHONE 12 pro max numbers for Antutu . My iPhone 12 Pro Max last score V8 . 3 . 8 was 656 , 629 the one before it was 648 , 229 . I have to say that Antutu is getting worse as a test because for iPhones the numbers are not consistent . My iPhone is pretty high I guess I ’ m lucky but I don ’ t think that is the reason .
# [2023-08-10 17:18:43] (2.3.1) Example 96: actually buying a <charger:Negative Confidence:0.6834> separately means you use more <packaging:Negative Confidence:0.8275> just for the charger , but also even more packaging by the delivery company , more trips taken by the delivery company to deliver the package , i . e . more <CO2 emissions:Negative Confidence:0.9977> , and also get inferior third party <headphones:Negative Confidence:0.9969> , in samsung ' s case of the premium AKG ones , therefore to wrap this up , in what way do you think this is in any way , " saving the planet " , yet alone " saving ur customer from losing brand loyalty ' cause you are removing stuff every year " ?
# [2023-08-10 17:18:43] (2.3.1) Example 97: Would really like to know if the <screen:Neutral Confidence:0.998> also has a 240hz touch polling rate like the Note 20 Ultra does . . . it ' s a noticeable difference and can ' t find that info anywhere .
# [2023-08-10 17:18:43] (2.3.1) Example 98: I got the s21 ultra , 128 GB Snapdragon . Its a beautiful phone , fixed the annoying photo blue fiasco from the 20 series . It ' s a slight annoyance not having the <SD card:Negative Confidence:0.9976> but 128 GB is more than enough for me . The headphones I couldnt care less about . The <charger:Negative Confidence:0.7857> I wish they added but it ' s not a big deal . The <screen:Positive Confidence:0.994> and <camera:Positive Confidence:0.9963> imo at the price more than make up for it . I recommend .
# [2023-08-10 17:18:43] (2.3.1) Example 99: Jun , 31 Jan 2021Charging sucks on the ultra . Without the <wall adapter:Negative Confidence:0.9971> it <charges:Negative Confidence:0.9971> really slow ( takes 5 - 6hrs to . . . moreWho cares how long it takes to <charge:Negative Confidence:0.9971> , my s20 ultra finished <charging:Negative Confidence:0.9979> about 30mins ago , its currently on 98 % and will probably be on 90 % when I wake up . I charge it once a day and it gets battered during that time .
# [2023-08-10 17:18:43] (2.3.1) Example 100: URSC0003 , 06 Feb 2021I find this S21 lineup completely nonsense and idiotic by Samsung leadership and lead architec . . . moreDual <sim:Negative Confidence:0.7834> is great , I have the s20 ultra , 2 sims , one <personal:Neutral Confidence:0.9273> , one for work . Most of my data is in Google drive at £2 . 49 per month for 200gb . Sorted .
# [2023-08-10 17:18:43] (2.3.1) Example 101: Anonymous , 10 Feb 2021Gsmarena reviews the <Exynos:Neutral Confidence:0.9991> version since they ' re based out of Europe . I ' d take exynos over snapdragon .
# [2023-08-10 17:18:43] (2.3.1) Example 102: Andrey , 27 Jan 2021With what version of the <processor:Neutral Confidence:0.9925> were the photos taken ? Exynos 2100 or Snapdragon 888 . Is th . . . moreGsmarena reviews the Exynos version since they ' re based out of Europe .
# [2023-08-10 17:18:43] (2.3.1) Example 103: Vj , 09 Feb 2021Charging a <battery:Negative Confidence:0.9803> to fast can not only be dangerous due to over heating but it also takes a t . . . moreWith your logic , even 22W charging is quite damaging . 5 or 10W charging is the best for prolonged battery <life:Positive Confidence:0.9206> .
# [2023-08-10 17:18:43] (2.3.1) Example 104: There needs to be another <battery:Neutral Confidence:0.9981> test run at 1080P and 60hz . There are many reviews on here that have figures for more than one <screen refresh rate:Neutral Confidence:0.999> setting , but not recent S21 reviews . I ' d be very interested in how much <battery life:Neutral Confidence:0.7367> this and the S21 + achieve at lower settings .
# [2023-08-10 17:18:43] (2.3.1) Example 105: URSC0003 , 06 Feb 2021I find this S21 lineup completely nonsense and idiotic by Samsung leadership and lead <architec:Negative Confidence:0.9993> . . . moreAbsolutely agree .
# [2023-08-10 17:18:43] (2.3.1) Example 106: Sam , 08 Feb 2021Did anyone know how many hz of <touch sensing:Neutral Confidence:0.9988> for S21 ultra ? <Touch:Neutral Confidence:0.9983> response is 240Hz
# [2023-08-10 17:18:43] (2.3.1) Example 107: ypcx , 01 Feb 2021Okay I may be whining too much . But 30 minutes from zero to full would be nicer . The tech is a . . . moreCharging a <battery:Negative Confidence:0.9948> to fast can not only be dangerous due to over heating but it also takes a toll on the <battery:Negative Confidence:0.9948> and can shorten the <battery:Negative Confidence:0.9948> life . So don ' t be in to big a hurry to charge it up .
# [2023-08-10 17:18:43] (2.3.1) Example 108: URSC0003 , 06 Feb 2021I find this S21 lineup completely nonsense and idiotic by Samsung leadership and lead architec . . . moreCompletely agree about the <charger:Negative Confidence:0.9977> . Its just a marketing stunt to get more out of the customers wallet by charging a huge <price:Negative Confidence:0.9877> for a Samsung brand charger . And removing the <expandable storage:Negative Confidence:0.9401> was a mistake . The fact that I could expand my memory up to 1TB on a micro sd card was always the deal maker for why I ' d choose a samsung phone over <iphones:Neutral Confidence:0.7755> . They do give you free 1TB cloud storage with Microsoft One Drive but , be assured that in the near future after they force most everybody over to Microsoft One Drive , I ' m sure they will start charging for it . Unfortunately I might as well switch to an Iphone since everyone in my family has one and just about everybody i know has an Iphone . Might as well join them .
# [2023-08-10 17:18:43] (2.3.1) Example 109: Sam , 08 Feb 2021Did anyone know how many hz of <touch sensing:Neutral Confidence:0.999> for S21 ultra ? 120hz
# [2023-08-10 17:18:43] (2.3.1) Example 110: thermal throttling will kill half of your <GPU perf:Negative Confidence:0.9981> after few minutes . These <chips:Negative Confidence:0.9987> are so HOOOOT
# [2023-08-10 17:18:43] (2.3.1) Example 111: Did anyone know how many hz of <touch sensing:Neutral Confidence:0.9973> for S21 ultra ?
# [2023-08-10 17:18:43] (2.3.1) Example 112: URSC0003 , 06 Feb 2021I find this <S21:Negative Confidence:0.999> lineup completely nonsense and idiotic by Samsung leadership and lead <architec:Negative Confidence:0.9992> . . . moreMe
# [2023-08-10 17:18:43] (2.3.1) Example 113: I find this S21 lineup completely nonsense and idiotic by Samsung leadership and lead architects who designed and gave their consent to produce it . 1 ) They removed <SD card:Negative Confidence:0.9723> and instead gave dual sim along with eSim support . Who the fuk uses 3 numbers on its phone ? With no roaming these days , people have stopped using dual SIMs on phone , its complete waste in my opinion . 2 ) If apple is eating shit , Samsung doesn ' t need to eat that shit by copying that and being a tail of apple . If you want to compete with apple then compete in good things like there <software support:Negative Confidence:0.9927> , <customer support:Negative Confidence:0.9949> etc instead of gimmicking people . 3 ) Removing <charger:Negative Confidence:0.9942> brick on the name of saving climate is like . . . as if we all are fool and don ' t understand that Samsung wants to mint more profit out of each sale . Instead remove the unnecessary paper work and provide longer <software support:Negative Confidence:0.9927> to its customers so that they can hold these phones for more number of years and reduce the pollution per head . 4 ) Selling plastic backs with low configuration at flagship prices is really ridiculous , why one should buy yours ? What better are you providing by charging the difference ? I look forward to see how this lineup perform in terms of sales . 3
# [2023-08-10 17:18:43] (2.3.1) Example 114: so now news that <exynos chip:Negative Confidence:0.9872> runs between 3200 and 4100 in multicore a large variation something causing this issue bug or heating or better chip makes sense as <cpu:Negative Confidence:0.4063> is clocked much higher but scores are same as snapdragon
# [2023-08-10 17:18:43] (2.3.1) Example 115: azrielnation , 01 Feb 2021camera looks bad at night . lots of noises and muddy . for big ass <lens:Negative Confidence:0.9991> , this a lil bit dissapointNot in night <mode:Negative Confidence:0.7764> it isn ' t , I ' ve got Exynos version and night mode is great , <auto:Negative Confidence:0.9971> isn ' t
# [2023-08-10 17:18:43] (2.3.1) Example 116: Anonymous , 04 Feb 2021yes it does have an option to record upto 4k videos in hdr 10 + . The feature debuted with the . . . more # 4
# [2023-08-10 17:18:43] (2.3.1) Example 117: Anonib , 03 Feb 2021Do Samsung use hdr10 + metadata to record their videos same as <iphone:Neutral Confidence:0.9991> use dolby vision hdr license ? yes it does have an option to record upto 4k videos in hdr 10 + . The feature debuted with the s10 series , a couple of years before apple introduced their dolby vision video recording compatibilities lol with the iPhone 12 series .
# [2023-08-10 17:18:43] (2.3.1) Example 118: Do Samsung use hdr10 + metadata to record their videos same as <iphone:Neutral Confidence:0.9992> use dolby vision hdr license ?
# [2023-08-10 17:18:43] (2.3.1) Example 119: Anonymous , 01 Feb 2021Complaining about <charging:Negative Confidence:0.9961> 6 hours Why don ' t get a new <charger:Neutral Confidence:0.6265> Get a <powerbank:Neutral Confidence:0.6096> .
# [2023-08-10 17:18:43] (2.3.1) Example 120: AnonD - 961600 , 01 Feb 2021True , looks like very rare people can afford the 512gb version . I received mine on Saturday . . . morei have samsung A50 6 / 64 variant . i have only filled up 42g <storage:Negative Confidence:0.9961> after 2 years of use since april 2019
# [2023-08-10 17:18:43] (2.3.1) Example 121: ypcx , 01 Feb 2021Okay I may be whining too much . But 30 minutes from zero to full would be nicer . The tech is a . . . moreYes graphene cells are out there , but the problem is they are not commercially available to the masses as of yet
# [2023-08-10 17:18:43] (2.3.1) Example 122: dazed1 , 27 Jan 2021Charging speed is already fixed , you should STOP thinking about numbers , and see the results . . . . moreOkay I may be whining too much . But 30 minutes from zero to full would be nicer . The tech is already out there ( graphene ) .
# [2023-08-10 17:18:43] (2.3.1) Example 123: Jun , 31 Jan 2021Charging sucks on the ultra . Without the <wall adapter:Negative Confidence:0.99> it <charges:Negative Confidence:0.998> really slow ( takes 5 - 6hrs to . . . moreComplaining about <charging:Negative Confidence:0.9954> 6 hours Why don ' t get a new charger
# [2023-08-10 17:18:43] (2.3.1) Example 124: [ deleted post ] Looks like you have this offer only for <Galaxy:Neutral Confidence:0.9988> S21 <forum:Neutral Confidence:0.9991> , you think that people here lack it a lot ? : - ) ( Reporting you anyway . )
# [2023-08-10 17:18:43] (2.3.1) Example 125: azrielnation , 01 Feb 2021camera looks bad at night . lots of noises and muddy . for big ass <lens:Negative Confidence:0.9987> , this a lil bit dissapointThe phone had 2 updates already and the second was for <performance:Negative Confidence:0.9384> and <camera:Negative Confidence:0.999> and I believe it will get even better over time .
# [2023-08-10 17:18:43] (2.3.1) Example 126: i0S . . . Never . . . Again , 26 Jan 2021114hr <Endurance:Negative Confidence:0.9336> with QHD @ 120hz . Meanwhile , Apple 12 Pro Max with lower resolution and ped . . . moreTo be fair , the <battery:Neutral Confidence:0.7657> test only consists of web browsing , video <playback:Negative Confidence:0.7528> and phone calls . The only area where 120hz is applied is during transitions between videos , and scrolling / loading the webpages . Don ' t forget that this phone can go as low as 5hz ( or whatever the minimum is ) as well .
# [2023-08-10 17:18:43] (2.3.1) Example 127: [ <deleted:Neutral Confidence:0.9549> post ] Love <phones:Positive Confidence:0.971> . That ' s why we are all here .
# [2023-08-10 17:18:43] (2.3.1) Example 128: camera looks bad at night . lots of noises and muddy . for big ass <lens:Negative Confidence:0.9993> , this a lil bit dissapoint
# [2023-08-10 17:18:43] (2.3.1) Example 129: Anonymous , 01 Feb 2021You charged using a <USB port:Neutral Confidence:0.4984> ? No surprise there , really . <USB 2 . 0 ports:Neutral Confidence:0.7825> charge at 5w a hour or 8w if USB 3 . 0 standard Samsung chargers 15 Watts or now 25 watts only charges at full <speed:Positive Confidence:0.6465> on a fast charger
# [2023-08-10 17:18:43] (2.3.1) Example 130: Jun , 31 Jan 2021Charging sucks on the ultra . Without the <wall adapter:Negative Confidence:0.9916> it <charges:Negative Confidence:0.9984> really slow ( takes 5 - 6hrs to . . . moreYou charged using a <USB port:Negative Confidence:0.9395> ? No surprise there , really .
# [2023-08-10 17:18:43] (2.3.1) Example 131: proUser , 30 Jan 2021Just seen demo piece at store . Its too huge to hold in one hand and heavy . I would still pre . . . moreI got the S21U 16gb <Ram:Negative Confidence:0.9899> . I ' ve rooted it . The <phone:Negative Confidence:0.9954> gets really hot too 55 The phone does not throttle , but instead it drains <battery:Negative Confidence:0.9966> much faster . 5000mah phone is now 4000mah after the root . 55 celcuis , I don ' t care or doesn ' t bother me , because it ' s hot on top right hand , so we all hold the phone at the middle bottom . Yea , but the phone is twice faster than standard , I ' m playing games at 70fps , <GPU:Negative Confidence:0.9863> has been raised to 1300mhz from 950mhz , severe <battery:Negative Confidence:0.9966> drain by 30 % than standard . Phone is super fast , . . Now it shows extreme and turbo on battery section , as well as high <performance:Negative Confidence:0.7838> and <power:Negative Confidence:0.7884> saving .
# [2023-08-10 17:18:43] (2.3.1) Example 132: AnonD - 973296 , 01 Feb 2021they guy under ur comment apparently didTrue , looks like very rare people can afford the 512gb version . I received mine on Saturday , got the silver <glass:Negative Confidence:0.7202> back one than the dull dead black frosty back . Prefer the glass because when you swipe it clean it , it ' s so shiny sparkling than Matt frost dull . I also have the Sony 5ii and Note20Ultra 512gb . What phone do you have ? I still have my Nokia 8800 Arte in gold and the carbon fibre .
# [2023-08-10 17:18:43] (2.3.1) Example 133: AnonD - 961600 , 31 Jan 2021has anyone bought the s21ultra 512gb <16gb ram:Neutral Confidence:0.7304> version ? they guy under ur comment apparently did
# [2023-08-10 17:18:43] (2.3.1) Example 134: Zoki , 31 Jan 2021Well if you are unhappy with it , I will be happy to deliver you from your suffering and I will . . . moreWhat you have no money or out off league to buy this ?
# [2023-08-10 17:18:43] (2.3.1) Example 135: has anyone bought the s21ultra 512gb <16gb ram:Neutral Confidence:0.9981> version ?
# [2023-08-10 17:18:43] (2.3.1) Example 136: I just got the S21Ultra 512gb <16gb Ram:Neutral Confidence:0.9983> version . Tried the 12gb <ram:Positive Confidence:0.9495> , 16gb <ram:Positive Confidence:0.9495> is wa better .
# [2023-08-10 17:18:43] (2.3.1) Example 137: Jun , 31 Jan 2021Charging sucks on the ultra . Without the <wall adapter:Negative Confidence:0.9984> it <charges:Negative Confidence:0.9986> really slow ( takes 5 - 6hrs to . . . moreWell if you are unhappy with it , I will be happy to deliver you from your suffering and I will gladly suffer instead of you , while using this phone . Happily
# [2023-08-10 17:18:43] (2.3.1) Example 138: I just got the S21Ultra 512gb <16gb Ram:Neutral Confidence:0.9983> version . Tried the 12gb <ram:Positive Confidence:0.9495> , 16gb <ram:Positive Confidence:0.9495> is wa better .
# [2023-08-10 17:18:43] (2.3.1) Example 139: Nick Tegrataker , 31 Jan 2021 ( Since the old reply to you has been deleted ) Thanks : ) Your most welcome
# ...
# [2023-08-10 17:18:43] (2.3.1) Example 4623: What is the battery endurance rating when the smooth <display:Neutral Confidence:0.8576> is turned off ? ( 60hz )
# [2023-08-10 17:18:43] (2.3.1) Example 4624: Over rated and others have long caught up . Even LG Wing took better lowlight <images:Positive Confidence:0.9959> in my eyes
# [2023-08-10 17:18:43] (2.3.1) Example 4625: Anonymous , 25 Oct 2020Where ' s the audio test and performance ? Just saying in summary " loud speakers " . . . moreWho gives a shit about speakers on a phone ? Nobody . Google knows that . You either have headphones on or it ' s on vibrate at work
# [2023-08-10 17:18:43] (2.3.1) Example 4626: As others have said , nothing special . It ' s weird that it feels like the 4a 5G would tick more boxes for someone who wants the basics ( stereo <speakers:Positive Confidence:0.6193> , <headphone jack:Neutral Confidence:0.9767> , <dual cam:Neutral Confidence:0.9413> , and solid - enough <battery:Positive Confidence:0.9955> ) . Google ' s going in the right direction . If they want to succeed next year , they should do : Pixel 5a with <Snapdragon:Neutral Confidence:0.6078> 690 ( makes no sense to give it the same <processor:Neutral Confidence:0.6572> as the ' flagship ' ) Pixel 6 with a 775 and 6 . 0 " display Pixel 6 XL with the same as above but with a 6 . 7 " display But the ' flagships ' need to come with 3 cameras , some bezel to house dual selfie cams again , FRONT - FACING stereo speakers , and the return of unlimited cloud photos storage . Make them come with all that while <pricing:Positive Confidence:0.8241> it well and I can see Pixel finally bringing in some solid devices .
# [2023-08-10 17:18:43] (2.3.1) Example 4627: I would really like that staff from GSMarena take pictures from standard locations from where they take pictures with all other smartphones . This way we really can not compare them side by side with Pixel device . Otherwise good and objective <review:Positive Confidence:0.9935> as always .
# [2023-08-10 17:18:43] (2.3.1) Example 4628: Ok so . This particular phone is wanted for two things : Stock experience and <Camera:Neutral Confidence:0.9926> . So i have 2 questions for GSMarena crew : 1 ) Why Pixel shots in general are in a Different location ? Presumably outside Europe ( Following the vivid atmosphere there ) - Other devices like Xiaomi ' s or Onepluses / Samsungs are i believe in Sofia ( Bulgaria ) so we can easily compare ourselves with our amateur or proficient knowledge of photography ? 2 ) Why there is always an underline or a biased text when reviewing a Pixel or a Google phone of the late era towards IN A NEGATIVE WAY ? - The Subtle " Never settle " shirt , passively aggressive | not being impressed by anything that this device offers " which happened way to many times in recent years . Pixel 5 is a Great phone , i mean great . <Form factor:Positive Confidence:0.9987> , Simplicity , Saves time and money and will be More consistent and More secure By A MILE then other android device . And You should emphasize that . That isn ' t a small feat . Improving <software:Neutral Confidence:0.9963> is important . Same or more then <hardware:Neutral Confidence:0.9964> .
# [2023-08-10 17:18:43] (2.3.1) Example 4629: I ' d love to buy this but I only just got the <4a:Positive Confidence:0.9993> .
# [2023-08-10 17:18:43] (2.3.1) Example 4630: Shriker , 25 Oct 2020 " The level of resolved detail is generally good " . Not sure what photos the reviewer . . . moreIf we are talking about detail , lets say that 8 years old Nokia 808 blows this ' <computational photography:Negative Confidence:0.9985> ' out of the window . Pretty poor <pics:Negative Confidence:0.9975> , if you ask me . I ' d rather hire a painter .
# [2023-08-10 17:18:43] (2.3.1) Example 4631: JamoaSoe , 25 Oct 2020Again a half baked review . Where ' s the <speaker:Negative Confidence:0.996> test ? <Camera:Negative Confidence:0.9964> comparisons also not in line . . . moreI think review was done in USA , while their office is in Bulgaria . Probably the reason .
# [2023-08-10 17:18:43] (2.3.1) Example 4632: Seems a bit passive aggressive for the reviewer to wear a OnePlus T shirt while taking Pixel review photos . Is it really an unbiased review that we love and expect from this site ?
# [2023-08-10 17:18:43] (2.3.1) Example 4633: Again a half baked review . Where ' s the <speaker:Negative Confidence:0.9457> test ? <Camera:Negative Confidence:0.8359> comparisons also not in line with the other smartphone reviews . You guys did the same with the OP8 Pro . Please publish the full review else don ' t do it at all .
# [2023-08-10 17:18:43] (2.3.1) Example 4634: Still too expensive for what you are getting . Google fails again with mediocre <hardware:Negative Confidence:0.9978> to impress .
# [2023-08-10 17:18:43] (2.3.1) Example 4635: Where ' s the audio test and performance ? Just saying in summary " loud speakers " doesn ' t give much away . Come on GSMArena . Under <screen:Negative Confidence:0.996> speaker doesn ' t fill me with confidence at all !
# [2023-08-10 17:18:43] (2.3.1) Example 4636: What ' s strange is that the 16 megapixel ultra wide angle photos are saved as 12 megapixel jpgs . Would be interesting to know the <resolution:Neutral Confidence:0.9746> of the ultra wide dng files .
# [2023-08-10 17:18:43] (2.3.1) Example 4637: Google hasn ' t brought back the white balance presets , very poor decision . More than 240 support forum users voted for the white balance presets . They simply don ' t listen to feedback at all . Google hasn ' t brought back HDR + enhanced , more than 170 support forum users voted for bringing back HDR + options . HDR + enhanced is better than Night Sight . When you use it with exposure compensation , it is nothing else than a fast Night Sight mode . While Night Sight takes up to 7s in extreme low - light conditions , HDR + enhanced takes up to 2 . 5s ( or 4s if you zoom ) , which is more similar to Apple ' s night mode , which takes up to 3s by default . Night Sight also often leads to slightly blurry photos , if you don ' t stop breathing for 7 seconds , that ' s another reason why HDR + enhanced is much better . It ' s disappointing that there is still no periscope camera and that they even replaced tele with an ultra wide angle camera , which doesn ' t even have autofocus for macro photos . Apparently you can still not edit HDR + raw files with the Google Photos app . As far as I know Apple ' s photo app will support editing raw files . And of course very disappointing that they still use the Imx 363 , which suffers extremely from dead pixels ( tested with multiple Pixel 3a ) that can not be removed with 3rd party software as Google ' s image processing transforms the dead pixels .
# [2023-08-10 17:18:43] (2.3.1) Example 4638: Good phone but where is the <sound:Negative Confidence:0.9925> review ?
# [2023-08-10 17:18:43] (2.3.1) Example 4639: " Since there ' s no longer a telephoto camera on the Pixel 5 and the ultra - wide doesn ' t feature an <autofocus lens:Negative Confidence:0.997> , the main camera no longer has this second eye to distinguish depth " I doubt that the missing <autofocus:Negative Confidence:0.995> is relevant for non - macro photos . Such ultra wide angle cameras have a very high <depth of field:Negative Confidence:0.9984> , so they don ' t need autofocus for sharp photos unless you want to take macro ( portrait ) photos .
# [2023-08-10 17:18:43] (2.3.1) Example 4640: Google is doing fine with their <phones:Positive Confidence:0.9908> . Some people may think Google is a bit behind in the cellphone game but this is the best 5th generation phone compared to all other companies previous release of their " 5 " model .
# [2023-08-10 17:18:43] (2.3.1) Example 4641: No word on <speakers:Neutral Confidence:0.9973> ?
# [2023-08-10 17:18:43] (2.3.1) Example 4642: I think the Pixel 5 is a solid phone . The <price:Positive Confidence:0.9952> is friendly coupled with the IP rated smaller form <factor:Positive Confidence:0.9809> . I do wish it was available in more countries . I also agree that the <hardware:Negative Confidence:0.7417> would need a major upgrade . Let ' s see the Pixel 5a / 6 next year hopefully . With that all said , give me your Pixel 5 unit rn
# [2023-08-10 17:18:43] (2.3.1) Example 4643: guys , where are my favourite photo compare tool photos . IMO you should ' t really bother releasing a review without those . The tool is what makes this site different from the dozens of other phone review sites . The rest is just specs that you can read anywhere . So emphasize on what makes you really different and provide photo compare tool shots .
# [2023-08-10 17:18:43] (2.3.1) Example 4644: Good review ! I am coming from a pixel 2xl and struggling to decide which phone to get . I love Pixel phones , simplicity and all of the Google <features:Positive Confidence:0.9905> . Yet I love to edit video on my phone , easier for me that way . I can do so on my pixel 2xl , but it is showing its age . Wondering how the 765 can handle that sort of stuff . I am tempted by the note 20 ultra , plenty of room to edit and shoot videos , but is the <camera:Negative Confidence:0.9613> as good ? And it ' s also so expensive . One plus 8 pro is a good compromise in <price:Negative Confidence:0.7945> , but the camera is not as good ? Or on par ? Just wish there was an XL version of the Pixel 5 or a Pixel 5 + version with all the specs .
# [2023-08-10 17:18:43] (2.3.1) Example 4645: or even better sony 5 II , much better having a <bezel:Positive Confidence:0.9974> than holes on the <screen:Neutral Confidence:0.9774> . . but it is missing <wireless charging:Negative Confidence:0.9993> . . . : ( ( (
# [2023-08-10 17:18:43] (2.3.1) Example 4646: Anonymous , 25 Oct 2020I actually quite like this phone and it ' s the first Pixel phone I like . It has a mod . . . moreAgree . First time I ' m considering a Pixel . But probably 4a 5G seems like a slightly better deal for 499 .
# [2023-08-10 17:18:43] (2.3.1) Example 4647: It seems like Google somewhat mitigated the issue from Pixel 4 where tons of noises are introduced to shadows and the corners when scenes have a wide dynamic range , even at the base ISO . I still find the output from Pixel 5 a bit too noisy and fuzzy for my liking , though . Google should use a larger <sensor:Negative Confidence:0.9869> for the next gen . product and bring telephoto <lens:Negative Confidence:0.9933> back , otherwise Pixel lineup will lose all the advantages they had in camera department over its rivals for years . The competition has caught up and is surpassing it right now while Google is still stumbling with stupid <hardware:Negative Confidence:0.9953> decisions , they seriously need to get their * * * * together .
# [2023-08-10 17:18:43] (2.3.1) Example 4648: Good phone but where is the <sound:Negative Confidence:0.9925> review ?
# [2023-08-10 17:18:43] (2.3.1) Example 4649: Shriker , 25 Oct 2020 " The level <of:Positive Confidence:0.9602> resolved detail is generally good " . Not sure what photos the reviewer . . . moreMi 10 Pro / Ultra , Galaxy S20 ( in 64MP mode ) , Mate 30 / P40 Pro , Mate 40 Pro + , etc . . To be honest it ' s not really hard for me to list them out . Pixel 5 does capture a lot of details for using such an inferiour set of <hardware:Positive Confidence:0.6928> , but I ' ve already seen many phones with significantly larger sensors outperforming it especially when it comes to <texture:Negative Confidence:0.5778> retention and noiselessness .
# [2023-08-10 17:18:43] (2.3.1) Example 4650: noting special
# [2023-08-10 17:18:43] (2.3.1) Example 4651: The only thing I like about this phone is ugly yet minimalist design
# [2023-08-10 17:18:43] (2.3.1) Example 4652: Anonymous , 25 Oct 2020I actually quite like this phone and it ' s the first Pixel phone I like . It has a mod . . . morepunch <hole:Negative Confidence:0.9914> is even worse than <notch:Negative Confidence:0.9952> lol . and on p5 you can ' t even hide it . . on other phones like s20fe or op 8t you can hide it , think ill skip p5 and go for one of those . .
# [2023-08-10 17:18:43] (2.3.1) Example 4653: I don ' t think lack of <headphone jack:Neutral Confidence:0.9167> is a problem with phones besides why do you need an headphone jack where wireless <connectivity:Positive Confidence:0.5181> is ruling
# [2023-08-10 17:18:43] (2.3.1) Example 4654: Nice phone but I don ' t like too much Google services
# [2023-08-10 17:18:43] (2.3.1) Example 4655: I actually quite like this phone and it ' s the first Pixel phone I like . It has a modern <design:Positive Confidence:0.9982> , nice <display:Positive Confidence:0.9983> without large top bezel or hideous notch , decent <battery life:Positive Confidence:0.9989> , sturdy <build:Positive Confidence:0.9987> ( not likely to break if I drop it ) , decent <cameras:Positive Confidence:0.9982> , <fast charging:Positive Confidence:0.9971> , <wireless charging:Positive Confidence:0.9964> , decent <processor:Positive Confidence:0.9963> , 5G and a fingerprint scanner ( yes , you need it when you ' re out and about with a mask on ) . And the <price:Positive Confidence:0.9923> is not too bad . I actually think Google should just keep making these midrange phones and stop competing in the flagship space where they ' re being outcompeted in every way . And if they do , they should think about getting rid of the lower tier " a " phones . They don ' t really need another set of midrangers .
# [2023-08-10 17:18:43] (2.3.1) Example 4656: Google should fire all cylinders and go full steam with high end phones irrespective of their sales . If they could deliver highend phones consistently every year with great camera , sure one day or the other it will be in the same league of <iphones:Neutral Confidence:0.9649> . Already pixels have a great software , the only thing stopping it in achieveing greatness is Googles inconsistent attitude . General Pixel cons are : Lack of <headphone jack:Negative Confidence:0.9977> No FM <Radio:Negative Confidence:0.9967> Compromise on Camera lens ( this is INEXCUSABLE ) Poor <battery life:Negative Confidence:0.9974> Lack of S - pen like feature .
# [2023-08-10 17:18:43] (2.3.1) Example 4657: Can you remove the Google search bar from the home screen ?
# [2023-08-10 17:18:43] (2.3.1) Example 4658: Missing <headphones jack:Negative Confidence:0.9938> , <SD card support:Negative Confidence:0.9885> are not considered as cons anymore ?
# [2023-08-10 17:18:43] (2.3.1) Example 4659: Shriker , 25 Oct 2020 " The level of resolved detail is generally good " . Not sure what photos the reviewer . . . moreEasy trick . Boost <colour:Positive Confidence:0.9859> contrast and <details:Positive Confidence:0.9931> are easier to see . Exactly what Google has done since Pixel 1 . Also apply tons of sharpening .
# [2023-08-10 17:18:43] (2.3.1) Example 4660: I ' m in love with this device . I want to buy , but my country IDN only allow registered IMEI of device to use local network providers , <google:Negative Confidence:0.9624> did not sell any phone in my country .
# [2023-08-10 17:18:43] (2.3.1) Example 4661: For the first time I skip new Pixels having had all previous models before ( except budget 3a ) . $ 700 for THIS is damn too much Google , sorry . I ' ll probably take my old Pixel 3 ( the best Pixel phone to my opinion ) out of the drawer and start using it again rather than buy P5 .
# [2023-08-10 17:18:43] (2.3.1) Example 4662: " The level of resolved <detail:Positive Confidence:0.9899> is generally good " . Not sure what photos the reviewer is looking at but , the ones in the review are outstanding and i challenge the author to find another phonecam that can take such detailed shots like that , consistently across the full frame , even if using manually downscaled 64 / 108mp images .
# [2023-08-10 17:18:43] (2.3.1) Example 4663: Pixel 4 = better design

# %% [markdown]
# The checkpoint parameter specifies the language for the pre-trained model. In this case, we use 'english' to load an English language model.
#
# The auto_device parameter is set to True by default, which means the model will be loaded on the available GPU if one is available. If you prefer to load the model on the CPU, you can set auto_device=False.
#
# Now, we have an initialized aspect extractor ready to identify and extract aspects from text data. Let's proceed with aspect extraction and explore the sentiment polarity associated with each aspect in the user reviews.

# %% [markdown]
# ## Output Format
# The output from the aspect extractor is a structured representation of the aspects found in the input text data. It typically includes the following information for each identified aspect:
#
# Aspect Term: The specific aspect or entity mentioned in the text.
# Positional Information: The start and end positions of the aspect term in the original text.
# Aspect Category: The category or type of the aspect. In ABSA, aspects are often classified into specific categories like "service," "price," "quality," etc.
# Sentiment Polarity: The sentiment polarity associated with the aspect. It indicates whether the sentiment expressed towards the aspect is positive, negative, or neutral.
#
# ### Utilizing Aspect Information
# The extracted aspects and their associated sentiment polarities provide valuable insights for further analysis. We can use this information to understand which aspects of a product or service are positively or negatively perceived by users. These insights can be leveraged for sentiment analysis, product improvement, and better customer satisfaction.
#
# Let's now leverage the aspect information and proceed with sentiment analysis to understand the overall sentiment expressed in user reviews.
